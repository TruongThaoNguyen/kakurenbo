6763 , 0.6772 , 0.6829 , 0.6943 , 0.6612 , 0.6717 , 0.6933 , 0.6877 , 0.686 , 0.6722 , 0.6785 , 0.6892 , 0.6892 , 0.7011 , 0.6772 , 0.692 , 0.7 , 0.6993 , 0.7102 , 0.6884 , 0.6774 , 0.6992 , 0.7089 , 0.7091 , 0.695 , 0.6972 , 0.7034 , 0.72 , 0.7167 , 0.7096 , 0.7089 , 0.7095 , 0.7126 , 0.7336 , 0.7042 , 0.7203 , 0.7197 , 0.7307 , 0.7284 , 0.7208 , 0.7288 , 0.7375 , 0.7336 , 0.7451 , 0.7464 , 0.7433 , 0.7487 , 0.7494 , 0.742 , 0.7403 , 0.728 , 0.7238 , 0.7292 , 0.7351 , 0.7378 , 0.7164 , 0.7132 , 0.7193 , 0.7277 , 0.7374 , 0.7449 , 0.7488 , 0.7514 , 0.751 , 0.7518 , 0.7514 , 0.7355 , 0.747 , 0.7539 , 0.7563 , 0.7578 , 0.7611 , 0.7587 , 0.7609 , 0.7532 , 0.7455 , 0.7508 , 0.7498 , 0.755 , 0.7506 , 0.7558 , 0.7612 , 0.7613 , 0.7584 , 0.7596 , 0.7612 , 0.7603 , 0.7611 , 0.76 , 0.7626 , 0.7628 , 0.7602 , 0.759 , 0.7594 , 0.7603 , 0.7655 , 0.7621 , 0.7628 , 0.7613 , 0.7634 , 0.7643 , 0.7635 , 0.7617 , 0.7623 , 0.7657 , 0.7615 , 0.7659 , 0.7622 , 0.7616 , 0.7636 , 0.7633 , 0.7614 , 0.7633 , 0.763 , 0.7634 , 0.7629 , 0.7635 , 0.763 , 0.7643 , 0.7656 , 0.767 , 0.7655 , 0.7663 , 0.7683 , 0.765 , 0.7641 , 0.7658 , 0.7651 , 0.7679 , 0.766 , 0.767 , 0.7687 , 0.7676 , 0.7661 , 0.7666 , 0.7656 , 0.7659 , 0.7677 , 0.7669]

# %%
len(test_acc)
# Out:
# 301

# %%
with open("results/SL/cifar100/GradMatchPB/ResNet18/0.7/1/1/result.json", "w") as f:
    json.dump(rs,f)

# %%
list_test_ac = []
list_time = []
with open("results/SL/cifar100/KAKURENBO/ResNet18/0.3/1/1/cifar100_KAKURENBO.log", "r") as f:
    for line in f:
        if "Test Accuracy" in line:
            a= line.split(",")
            time_ = a[-3].split("Test Accuracy: ")
            list_test_ac.append(float(a[-3].split("Test Accuracy: ")[1][:-1]))
            list_time.append(float(a[-1].split("Timing: ")[1].split("\n")[0]))

# %%
fraction_list = []
with open("results/SL/cifar100/KAKURENBO/ResNet18/0.3/1/1/cifar100_KAKURENBO.log", "r") as f:
    for line in f:
        if " Training " not in line:
            if "Model" not in line:
                fraction_list.append(float(line.split("INFO: ")[-1].split("\n")[0]))

# %%
import numpy as np
time = list(np.array(list_time)[1:] - np.array(list_time)[:-1])

# %%
import json
rs = {}
rs['epoch_time'] = time
rs['test_acc'] = list_test_ac
rs['fraction'] = fraction_list
with open("results/SL/cifar100/KAKURENBO/ResNet18/0.3/5/1/result.json", "w") as f:
    json.dump(rs,f)
